# %% [markdown]
# <a href="https://colab.research.google.com/github/sreePradeepRanjan/pradeep/blob/main/cse_assignment_1(2022333550).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install pandas

# %%
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv(path +"/2500 Concrete design mixes.csv")
df.head()
# Out:
#    Unnamed: 0 Type_of_course_Aggregate Type_of_Fine_Aggregate_  \
# 0           0                  Crushed                 Natural
# 1           1                  Crushed                 Natural
# 2           2                  Crushed                 Natural
# 3           3                  Natural                 Natural
# 4           4                  Natural                 Natural
#
#   Max._Size_of_Coarse_Aggregate_(mm)  Passing_0.6_mm_Sieve_(%)  \
# 0                                 40                       0.0
# 1                                 40                       0.0
# 2                                 20                      45.6
# 3                                 20                      57.9
# 4                                 20                      19.5
#
#   Target_Mean_Strength_(N/mm2)  Cement_O.P.C_(Kg/m3)  W/C_Ratio  \
# 0                           43                 365.0       0.52
# 1                     CALcrete                 365.0       0.52
# ...
